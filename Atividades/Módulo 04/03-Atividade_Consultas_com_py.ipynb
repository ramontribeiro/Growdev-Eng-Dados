# %% [markdown]
# Você já criou o banco de dados, já criou as tabelas e inseriu os dados.
# Praticamos até aqui a arquitetura de um banco de dados, DDl, DML para criar as tabelas e
# inserir, deletar e manipular dados dentro do nosso banco.

# %% [markdown]
# # instalações:

# %%
pip install psycopg2 pandas
# Out:
# Requirement already satisfied: psycopg2 in ./.venv/lib/python3.12/site-packages (2.9.9)
# Collecting pandas
#   Using cached pandas-2.2.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (19 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Using cached numpy-2.0.1-cp312-cp312-macosx_14_0_arm64.whl.metadata (60 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Using cached pandas-2.2.2-cp312-cp312-macosx_11_0_arm64.whl (11.3 MB)
# Using cached numpy-2.0.1-cp312-cp312-macosx_14_0_arm64.whl (5.0 MB)
# Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Installing collected packages: pytz, tzdata, numpy, pandas
# Successfully installed numpy-2.0.1 pandas-2.2.2 pytz-2024.1 tzdata-2024.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import psycopg2
import pandas

# %% [markdown]
# #### Se conectar ao banco:

# %%
# Conectando ao banco de dados
conn = psycopg2.connect(
    dbname="seu_banco_de_dados",
    user="seu_usuario",
    password="sua_senha",
    host="localhost",  # ou outro host onde seu banco de dados está localizado
    port="5432"
)
cursor = conn.cursor()

# %% [markdown]
# #### 1. Selecione todos produtos de uma categoria.

# %%
def select_products_by_category(category):
    query = "SELECT * FROM Produtos WHERE Categoria = %s"
    cursor.execute(query, (category,))
    return cursor.fetchall()

# %% [markdown]
# #### 2. Nome e endereço dos clientes que fizeram um pedido em 2024

# %%
def select_clients_orders_2024():
    query = """
    SELECT c.Nome, c.Endereco
    FROM Clientes c
    JOIN Pedidos p ON c.ID_Cliente = p.ID_Cliente
    WHERE EXTRACT(YEAR FROM p.Data_Pedido) = 2024
    """
    cursor.execute(query)
    return cursor.fetchall()

# %% [markdown]
# #### 3. Produtos com preço entre 50 e 100:

# %%
def select_products_price_range():
    query = "SELECT * FROM Produtos WHERE Preco BETWEEN 50 AND 100"
    cursor.execute(query)
    return cursor.fetchall()

# %% [markdown]
# #### 4. Número total de pedidos feitos em julho de 2024:

# %%
def count_orders_july_2024():
    query = """
    SELECT COUNT(*) AS Total_Pedidos
    FROM Pedidos
    WHERE EXTRACT(YEAR FROM Data_Pedido) = 2024
      AND EXTRACT(MONTH FROM Data_Pedido) = 7
    """
    cursor.execute(query)
    return cursor.fetchone()

# %% [markdown]
# #### 5. Total pago por cada pedido:

# %%
def total_paid_per_order():
    query = "SELECT ID_Pedido, SUM(Valor_Pago) AS Total_Pago FROM Pagamentos GROUP BY ID_Pedido"
    cursor.execute(query)
    return cursor.fetchall()

# %% [markdown]
# #### 6. Nome dos clientes e valor total dos seus pedidos

# %%
def total_value_per_client():
    query = """
    SELECT c.Nome, SUM(p.Valor_Total) AS Total_Pedido
    FROM Clientes c
    JOIN Pedidos p ON c.ID_Cliente = p.ID_Cliente
    GROUP BY c.Nome
    """
    cursor.execute(query)
    return cursor.fetchall()

# %% [markdown]
# #### 7. Produtos com estoque menor que 10:

# %%
def products_low_stock():
    query = "SELECT * FROM Produtos WHERE Estoque < 10"
    cursor.execute(query)
    return cursor.fetchall()

# %% [markdown]
# #### 8. Pedidos com status e quantidade de itens em cada pedido:

# %%
def orders_with_item_count():
    query = """
    SELECT p.ID_Pedido, p.Status, COUNT(i.ID_Item) AS Quantidade_Itens
    FROM Pedidos p
    JOIN Itens_Pedido i ON p.ID_Pedido = i.ID_Pedido
    GROUP BY p.ID_Pedido, p.Status
    """
    cursor.execute(query)
    return cursor.fetchall()

# %% [markdown]
# #### 9. Produtos que não foram vendidos em nenhum pedido:

# %%
def unsold_products():
    query = """
    SELECT * FROM Produtos
    WHERE ID_Produto NOT IN (
        SELECT DISTINCT ID_Produto
        FROM Itens_Pedido
    )
    """
    cursor.execute(query)
    return cursor.fetchall()

# %% [markdown]
# #### 10. Os 10 maiores clientes por quantidade de pedidos:

# %%
def top_10_clients_by_orders():
    query = """
    SELECT c.Nome, COUNT(p.ID_Pedido) AS Quantidade_Pedidos
    FROM Clientes c
    JOIN Pedidos p ON c.ID_Cliente = p.ID_Cliente
    GROUP BY c.Nome
    ORDER BY Quantidade_Pedidos DESC
    LIMIT 10
    """
    cursor.execute(query)
    return cursor.fetchall()

# %% [markdown]
# #### 11. Produto mais caro e mais barato:

# %%
def most_and_least_expensive_products():
    query = """
    SELECT 'Mais Caro' AS Tipo, ID_Produto, Nome, Descricao, Preco, Estoque, Categoria
    FROM (
        SELECT * FROM Produtos
        ORDER BY Preco DESC
        LIMIT 1
    ) AS Mais_Caro

    UNION ALL

    SELECT 'Mais Barato' AS Tipo, ID_Produto, Nome, Descricao, Preco, Estoque, Categoria
    FROM (
        SELECT * FROM Produtos
        ORDER BY Preco ASC
        LIMIT 1
    ) AS Mais_Barato
    """
    cursor.execute(query)
    return cursor.fetchall()

# %% [markdown]
# #### 12. Idade média dos clientes:

# %%
def average_client_age():
    query = "SELECT AVG(EXTRACT(YEAR FROM AGE(Data_Nascimento))) AS Idade_Media FROM Clientes"
    cursor.execute(query)
    return cursor.fetchone()

# %% [markdown]
# #### 13. Clientes que possuem o mesmo sobrenome:

# %%
def clients_with_same_last_name():
    query = """
    SELECT Nome, COUNT(*) AS Quantidade
    FROM Clientes
    GROUP BY Nome
    HAVING COUNT(*) > 1
    """
    cursor.execute(query)
    return cursor.fetchall()

# %% [markdown]
# #### 14. Pedidos feitos por clientes cujo nome começa com 'A':

# %%
def orders_by_clients_name_starts_with_A():
    query = """
    SELECT p.*
    FROM Pedidos p
    JOIN Clientes c ON p.ID_Cliente = c.ID_Cliente
    WHERE c.Nome LIKE 'A%'
    """
    cursor.execute(query)
    return cursor.fetchall()

# %% [markdown]
# #### 15. Produtos, sua categoria e indicação de estoque:

# %%
def products_with_stock_status():
    query = """
    SELECT Nome, Categoria,
           CASE 
               WHEN Estoque > 0 THEN 'Em Estoque'
               ELSE 'Esgotado'
           END AS Status_Estoque
    FROM Produtos
    """
    cursor.execute(query)
    return cursor.fetchall()

# %% [markdown]
# #### Exemplo de chamada de função e exibição dos resultados:

# %%
if __name__ == "__main__":
    print(select_products_by_category('Eletrônicos'))
    print(select_clients_orders_2024())
    print(select_products_price_range())
    print(count_orders_july_2024())
    print(total_paid_per_order())
    print(total_value_per_client())
    print(products_low_stock())
    print(orders_with_item_count())
    print(unsold_products())
    print(top_10_clients_by_orders())
    print(most_and_least_expensive_products())
    print(average_client_age())
    print(clients_with_same_last_name())
    print(orders_by_clients_name_starts_with_A())
    print(products_with_stock_status())
# Out:
# [(2, 'key', 'Me effect detail laugh family perhaps anything beyond.', Decimal('276.75'), 90, 'Eletrônicos'), (5, 'institution', 'Already agency trip.', Decimal('220.61'), 84, 'Eletrônicos'), (6, 'bar', 'Teacher beautiful authority rule.', Decimal('609.60'), 71, 'Eletrônicos'), (12, 'identify', 'Per better nor half.', Decimal('580.89'), 16, 'Eletrônicos'), (18, 'impact', 'Daughter join apply lawyer yet address.', Decimal('558.72'), 85, 'Eletrônicos'), (21, 'southern', 'Interview Mr season system newspaper decade remember part.', Decimal('762.80'), 72, 'Eletrônicos'), (22, 'happy', 'Next customer which blood society for.', Decimal('738.21'), 12, 'Eletrônicos'), (28, 'fill', 'Although skill open Republican production student.', Decimal('933.55'), 63, 'Eletrônicos'), (33, 'oil', 'Meet east history sport.', Decimal('272.22'), 24, 'Eletrônicos'), (39, 'especially', 'Entire training better offer discussion.', Decimal('735.93'), 62, 'Eletrônicos'), (40, 'glass', 'Break environmental position.', Decimal('961.65'), 29, 'Eletrônicos'), (41, 'type', 'Loss contain cup wish collection total.', Decimal('219.13'), 42, 'Eletrônicos'), (43, 'teach', 'Ground director hear about stuff suddenly.', Decimal('98.36'), 48, 'Eletrônicos'), (48, 'man', 'Other than another half everything.', Decimal('666.24'), 49, 'Eletrônicos'), (52, 'along', 'Act race gas think security.', Decimal('36.15'), 13, 'Eletrônicos'), (53, 'action', 'South serious present full activity free.', Decimal('837.61'), 5, 'Eletrônicos'), (62, 'health', 'Usually great guy popular trial.', Decimal('996.73'), 47, 'Eletrônicos'), (66, 'four', 'Citizen quickly mother feel administration.', Decimal('201.76'), 48, 'Eletrônicos'), (69, 'develop', 'Case day board the trip value institution.', Decimal('992.73'), 76, 'Eletrônicos'), (77, 'fill', 'Everyone suddenly hope.', Decimal('564.96'), 53, 'Eletrônicos'), (78, 'sure', 'Coach left relate today second.', Decimal('589.42'), 1, 'Eletrônicos'), (82, 'security', 'Executive TV newspaper case.', Decimal('846.56'), 18, 'Eletrônicos'), (83, 'summer', 'Party operation window rate body.', Decimal('64.65'), 93, 'Eletrônicos'), (94, 'program', 'Evidence case already mission focus pretty camera.', Decimal('20.66'), 58, 'Eletrônicos'), (95, 'science', 'Agent fire out step newspaper direction whom.', Decimal('929.29'), 93, 'Eletrônicos'), (96, 'player', 'Allow ability interesting discover.', Decimal('815.46'), 17, 'Eletrônicos'), (119, 'beyond', 'My blood happen challenge answer investment especially.', Decimal('746.05'), 97, 'Eletrônicos'), (121, 'change', 'Language budget could work.', Decimal('231.13'), 97, 'Eletrônicos'), (132, 'add', 'Begin move while material though east real.', Decimal('704.22'), 32, 'Eletrônicos'), (138, 'every', 'Commercial represent again part often they option.', Decimal('925.36'), 46, 'Eletrônicos'), (139, 'end', 'Statement part wide within house new player federal.', Decimal('842.85'), 69, 'Eletrônicos'), (143, 'consumer', 'Laugh life somebody prove here.', Decimal('604.51'), 82, 'Eletrônicos'), (154, 'compare', 'Give magazine season seem poor city.', Decimal('143.34'), 9, 'Eletrônicos'), (163, 'since', 'Follow market rather up require.', Decimal('957.08'), 85, 'Eletrônicos'), (165, 'husband', 'Follow scientist for firm.', Decimal('202.23'), 45, 'Eletrônicos'), (167, 'control', 'Serious view yeah wear contain.', Decimal('704.80'), 39, 'Eletrônicos'), (171, 'every', 'Different force business test.', Decimal('537.50'), 53, 'Eletrônicos'), (179, 'result', 'Memory along because.', Decimal('864.30'), 88, 'Eletrônicos'), (188, 'care', 'East investment TV there agree.', Decimal('46.91'), 7, 'Eletrônicos'), (192, 'really', 'Serious mouth husband without sell should meeting material.', Decimal('913.95'), 67, 'Eletrônicos'), (195, 'action', 'Camera product sea site ago note and.', Decimal('431.29'), 85, 'Eletrônicos'), (197, 'level', 'Manage half day professional bill.', Decimal('309.60'), 53, 'Eletrônicos'), (203, 'day', 'Dream partner ...
# [('David Rhodes', '67678 Castillo Ports Suite 690\nWest Richardland, VI 44379'), ('Jake Vasquez', 'PSC 3250, Box 0193\nAPO AP 85313'), ('James Daniels', '691 Richard Flat Apt. 564\nAlicialand, IA 32372'), ('Krista Singleton', '19052 Kimberly Drive\nNorth Melissa, RI 75545'), ('Lisa Murray', '5251 Jason Flats Apt. 454\nScottville, TX 41331'), ('Caleb Harris', '74194 Tiffany Valleys Suite 745\nNew Zachary, ID 07493'), ('Victoria Moore', '279 Smith Avenue\nSouth Karenport, FM 05527'), ('Riley Barrett', '46696 Deborah Summit\nKingtown, GA 09847'), ('Stephanie Rogers', '9257 Coleman Path Suite 368\nNorth Bobbymouth, KS 08976'), ('Christine Gonzalez', '28685 Palmer Summit\nPort Richardport, NH 37260'), ('Karen Cox', '47027 Solomon Haven Apt. 057\nBryantborough, MO 58653'), ('John Chavez', '4730 Bailey Keys Apt. 232\nWest Ryanburgh, LA 49861'), ('Matthew Johnson', '9108 Andrea Points Suite 489\nBarrettfurt, OH 81642'), ('Alison Burke', '08500 Holmes Land\nSouth Donnaview, MD 11742'), ('Spencer Rodgers MD', '4800 Cruz Isle\nNorth Devin, AS 50668'), ('Charles Brown', '403 Edward Plain Suite 683\nWest Louis, HI 37544'), ('Alexander Johnson', '65508 Beth Glen Suite 255\nEast Donnafurt, AL 93229'), ('Hannah Simpson', '7376 Alexandra Ridge Suite 023\nWest Matthewtown, VA 08809'), ('Kimberly Peters', '71918 Jessica Circles\nFloreshaven, IA 40857'), ('Laura Garcia', '373 Taylor Burg Suite 979\nNew Katherineport, UT 56154'), ('Shannon Marshall', '08202 Little Ports\nPort Joefort, OK 44586'), ('Wesley Burns', 'USNV Ross\nFPO AP 14692'), ('Caleb Carter', '930 Gregory Village\nMorrisville, WY 91236'), ('Andre Yates', '0352 Stacy Fields Apt. 907\nNorth Mark, CO 74539'), ('Ron
# [(29, 'outside', 'Indeed this up.', Decimal('56.53'), 35, 'Livros'), (38, 'fall', 'Hotel across others include owner help single.', Decimal('55.38'), 43, 'Móveis'), (43, 'teach', 'Ground director hear about stuff suddenly.', Decimal('98.36'), 48, 'Eletrônicos'), (61, 'operation', 'Lay write where behavior.', Decimal('98.85'), 67, 'Alimentos'), (83, 'summer', 'Party operation window rate body.', Decimal('64.65'), 93, 'Eletrônicos'), (109, 'even', 'Election term maybe money away full always.', Decimal('72.70'), 36, 'Roupas'), (145, 'question', 'Represent lay community both skin their city.', Decimal('85.03'), 85, 'Móveis'), (175, 'body', 'System imagine mean small.', Decimal('92.40'), 38, 'Livros'), (189, 'road', 'Tv cold official save that husband.', Decimal('66.28'), 47, 'Alimentos'), (190, 'eat', 'Face animal board.', Decimal('64.30'), 54, 'Alimentos'), (219, 'also', 'Color star car fear leave recent.', Decimal('52.15'), 5, 'Eletrônicos'), (282, 'then', 'Structure picture federal real.', Decimal('93.19'), 84, 'Livros'), (318, 'color', 'Fact class part.', Decimal('96.93'), 84, 'Roupas'), (340, 'read', 'Eat bed ahead tell around hold opportunity.', Decimal('85.69'), 75, 'Livros'), (353, 'create', 'Success strong left manage subject.', Decimal('95.12'), 60, 'Móveis'), (361, 'here', 'Even so three listen service deep act.', Decimal('87.26'), 59, 'Livros'), (379, 'chair', 'So kind industry shoulder.', Decimal('86.01'), 63, 'Eletrônicos'), (381, 'administration', 'Reflect name color whom could start police.', Decimal('73.83'), 64, 'Alimentos'), (385, 'huge', 'Rock test day matter out none.', Decimal('72.56'), 94, 'Móveis'), (415, 'husband', 'Mr man under kitchen catch.', Decimal('76.70'), 49, 'Eletrônicos'), (417, 'election', 'Catch evidence present whom.', Decimal('61.96'), 62, 'Roupas'), (452, 'head', 'Measure hotel analysis.', Decimal('75.90'), 41, 'Alimentos'), (463, 'reason', 'Maybe figure pick son itself walk six.', Decimal('55.83'), 25, 'Móveis'), (472, 'whatever', 'Than daughter make.', Decimal('52.69'), 41, 'Móveis'), (474, 'coach', 'Weight computer need think admit watch before.', Decimal('93.22'), 92, 'Roupas'), (531, 'their', 'Serve enough account end.', Decimal('59.47'), 27, 'Móveis'), (539, 'either', 'Make population himself.', Decimal('63.44'), 47, 'Alimentos'), (620, 'follow', 'Since provide spring fly medical believe audience yeah.', Decimal('93.40'), 26, 'Livros'), (649, 'pass', 'Provide study main hot good.', Decimal('51.00'), 71, 'Eletrônicos'), (662, 'want', 'Fall identify establish food level.', Decimal('58.17'), 31, 'Roupas'), (673, 'recent', 'Hot man full safe country truth wonder try.', Decimal('70.23'), 54, 'Roupas'), (677, 'however', 'City list happy article.', Decimal('94.34'), 55, 'Móveis'), (684, 'simply', 'Help while that west also.', Decimal('79.18'), 88, 'Alimentos'), (730, 'remember', 'Camera forget bag left.', Decimal('56.62'), 14, 'Livros'), (741, 'form', 'Rock sell activity there happen speak see easy.', Decimal('81.70'), 6, 'Livros'), (742, 'well', 'Idea thing key choice mean.', Decimal('53.27'), 57, 'Eletrônicos'), (765, 'plant', 'Summer physical large soon war window.', Decimal('60.45'), 33, 'Roupas'), (804, 'herself', 'Month artist deal build.', Decimal('87.54'), 27, 'Eletrônicos'), (818, 'wear', 'Military as sit compare pressure Democrat take.', Decimal('91.42'), 47, 'Móveis'),
# [(7, 'very', 'Certainly smile why large.', Decimal('19.78'), 2, 'Roupas'), (9, 'yeah', 'Along impact build center moment.', Decimal('482.39'), 3, 'Roupas'), (24, 'option', 'People social visit age consumer.', Decimal('203.51'), 3, 'Roupas'), (42, 'should', 'Choose finish information air book today.', Decimal('500.89'), 6, 'Roupas'), (44, 'despite', 'Its improve avoid power.', Decimal('766.17'), 1, 'Alimentos'), (53, 'action', 'South serious present full activity free.', Decimal('837.61'), 5, 'Eletrônicos'), (60, 'perform', 'Plant raise special type act.', Decimal('985.23'), 4, 'Roupas'), (78, 'sure', 'Coach left relate today second.', Decimal('589.42'), 1, 'Eletrônicos'), (101, 'increase', 'There culture surface value likely.', Decimal('854.26'), 5, 'Móveis'), (128, 'financial', 'Remain scene dog record.', Decimal('761.26'), 8, 'Roupas'), (131, 'same', 'Court senior none measure act many.', Decimal('487.36'), 5, 'Alimentos'), (133, 'morning', 'Huge couple under if blue theory.', Decimal('690.45'), 6, 'Roupas'), (142, 'into', 'Capital up yet when store quickly.', Decimal('667.95'), 9, 'Roupas'), (154, 'compare', 'Give magazine season seem poor city.', Decimal('143.34'), 9, 'Eletrônicos'), (174, 'deal', 'Line staff research cultural mean process forget.', Decimal('106.80'), 4, 'Livros'), (188, 'care', 'East investment TV there agree.', Decimal('46.91'), 7, 'Eletrônicos'), (207, 'defense', 'Wide challenge tax.', Decimal('803.36'), 3, 'Móveis'), (212, 'personal', 'Across matter trial security force between rich method.', Decimal('162.30'), 1, 'Móveis'), (219, 'also', 'Color star car fear leave recent.', Decimal('52.15'), 5, 'Eletrônicos'), (232, 'someone', 'Guy shake market believe attention reason statement.', Decimal('988.15'), 2, 'Móveis'), (235, 'man', 'Stock stuff expert well gas.', Decimal('638.30'), 9, 'Roupas'), (242, 'whether', 'Board official can article property.', Decimal('370.96'), 1, 'Roupas'), (243, 'offer', 'Oil cause recent treat.', Decimal('167.35'), 9, 'Livros'), (303, 'former', 'Miss win along fact lawyer.', Decimal('418.44'), 6, 'Eletrônicos'), (310, 'body', 'Visit particular story more probably.', Decimal('827.94'), 4, 'Alimentos'), (345, 'think', 'Child political since accept.', Decimal('563.36'), 3, 'Eletrônicos'), (349, 'through', 'She glass note education.', Decimal('515.80'), 4, 'Móveis'), (359, 'her', 'Month car tell mind now kind off.', Decimal('907.43'), 4, 'Alimentos'), (365, 'ahead', 'Fast particular never someone even politics fire.', Decimal('858.14'), 4, 'Livros'), (366, 'story', 'Lay education answer.', Decimal('790.28'), 8, 'Eletrônicos'), (392, 'condition', 'Development radio particularly air.', Decimal('927.12'), 9, 'Alimentos'), (412, 'ground', 'Effect traditional summer significant law operation.', Decimal('190.77'), 1, 'Roupas'), (416, 'shoulder', 'From difficult skill probably.', Decimal('712.90'), 7, 'Eletrônicos'), (435, 'business', 'Citizen leg agent.', Decimal('161.81'), 4, 'Livros'), (437, 'others', 'Fall lay easy.', Decimal('576.36'), 6, 'Móveis'), (439, 'art', 'Participant away nice total street from they.', Decimal('335.77'), 8, 'Móveis'), (442, 'agreement', 'Consumer rock run.', Decimal('750.65'), 5, 'Móveis'), (456, 'bag', 'History of series product.', Decimal('502.72'), 9, 'Móveis'), (457, 'discuss', 'History mission project just.', Decimal('577.05'), 8, 'Móveis'), (491, 'tend', 'Back discuss late success.', Decimal('481.16'), 8, 'Móveis'), (492, 'sport', 'Rate impact decision.', Decimal('176.39'), 4, 'Roupas'), (509, 'stay', 'Control lot cause.', Decimal('935.61'), 6, 'Livros'), (515, 'matter', 'Popular head role however me.', Decimal('792.12'), 8, 'Livros'), (526, 'heavy', 'Election involve just sense consumer.', Decimal('109.08'), 2, 'Roupas'), (545, 'play', 'Family brother nice tonight.', Decimal('457.08'), 5, 'Roupas'), (592, 'hope', 'Individual change drug above throughout.', Decimal('398.82'), 1, 'Roupas'), (612, 'property', 'Door minute decide young serious group us.',  ...
# [(3936, 'Pendente', 1), (5761, 'Concluído', 2), (5468, 'Cancelado', 1), (7662, 'Cancelado', 1), (4326, 'Concluído', 2), (2466, 'Pendente', 2), (5697, 'Pendente', 1), (1750, 'Cancelado', 1), (5230, 'Cancelado', 1), (4993, 'Pendente', 1), (6373, 'Concluído', 1), (10628, 'Concluído', 1), (2784, 'Cancelado', 2), (1552, 'Concluído', 1), (5001, 'Pendente', 1), (5038, 'Cancelado', 1), (1811, 'Concluído', 1), (2204, 'Concluído', 2), (1373, 'Pendente', 1), (764, 'Concluído', 1), (3762, 'Cancelado', 2), (1268, 'Pendente', 1), (2749, 'Pendente', 1), (3202, 'Cancelado', 3), (6905, 'Concluído', 1), (8057, 'Cancelado', 1), (10454, 'Pendente', 1), (7499, 'Concluído', 1), (1595, 'Cancelado', 2), (10430, 'Cancelado', 2), (4095, 'Pendente', 1), (4611, 'Pendente', 1), (2990, 'Cancelado', 1), (4289, 'Concluído', 1), (815, 'Cancelado', 1), (8660, 'Cancelado', 2), (8724, 'Concluído', 2), (8457, 'Concluído', 1), (2721, 'Pendente', 2), (4452, 'Pendente', 1), (8228, 'Concluído', 1), (9306, 'Cancelado', 1), (6861, 'Cancelado', 2), (5644, 'Cancelado', 1), (2366, 'Pendente', 1), (4634, 'Cancelado', 2), (1287, 'Pendente', 2), (1550, 'Pendente', 2), (6258, 'Cancelado', 1), (3840, 'Concluído', 3), (3199, 'Pendente', 1), (6445, 'Concluído', 1), (7064, 'Pendente', 1), (743, 'Concluído', 4), (10200, 'Pendente', 1), (3986, 'Pendente', 2), (9313, 'Pendente', 1), (3068, 'Cancelado', 1), (2773, 'Pendente', 2), (2544, 'Cancelado', 2), (5754, 'Pendente', 1), (6219, 'Concluído', 3), (6626, 'Pendente', 3), (5763, 'Concluído', 1), (4689, 'Cancelado', 1), (1319, 'Cancelado', 2), (1603, 'Concluído', 1), (1522, 'Concluído', 1), (1967, 'Cancelado', 1), (6095, 'Cancelado', 1), (6084, 'Cancelado', 1), (2742, 'Concluído', 3), (8711, 'Concluído', 2), (10214, 'Cancelado', 2), (3046, 'Concluído', 2), (9492, 'Cancelado', 2), (9079, 'Concluído', 2), (8613, 'Cancelado', 2), (10385, 'Pendente', 1), (5581, 'Cancelado', 1), (9259, 'Concluído', 1), (5208, 'Pendente', 1), (6716, 'Cancelado', 1), (9685, 'Pendente', 2), (4351, 'Cancelado', 1), (1549, 'Cancelado', 1), (3463, 'Pendente', 1), (667, 'Cancelado', 2), (8401, 'Cancelado', 1), (9771, 'Concluído', 1), (4645, 'Cancelado', 2), (2073, 'Concluído', 2), (9890, 'Cancelado', 3), (8475, 'Pendente', 2), (1044, 'Pendente', 3), (4893, 'Cancelado', 2), (4967, 'Concluído', 2), (3671, 'Concluído', 3), (8009, 'Concluído', 1), (7942, 'Cancelado', 2), (6631, 'Cancelado', 1), (9647, 'Concluído', 2), (7691, 'Concluído', 1), (1144, 'Concluído', 1), (4719, 'Concluído', 2), (1987, 'Cancelado', 2), (6912, 'Pendente', 2), (9661, 'Concluído', 1), (2951, 'Concluído', 1), (944, 'Pendente', 1), (6331, 'Cancelado', 2), (2601, 'Pendente', 3), (8954, 'Cancelado', 1), (4921, 'Cancelado', 3), (10352, 'Concluído', 1), (7900, 'Concluído', 1), (948, 'Pendente', 1), (8267, 'Pendente', 1), (1540, 'Cancelado', 1), (6086, 'Concluído', 1), (981, 'Pendente', 2), (8118, 'Cancelado', 1), (8366, 'Pendente', 2), (5628, 'Pendente', 2), (9413, 'Concluído', 1), (6473, 'Concluído', 1), (10188, 'Cancelado', 1), (7520, 'Pendente', 1), (10042, 'Concluído', 1), (972, 'Cancelado', 1), (3890, 'Pendente', 2), (6329, 'Pendente', 2), (3374, 'Concluído', 2), (5352, 'Pendente', 3), (3682, 'Concluído', 3), (8841, 'Pendente', 2), (7541, 'Pendente', 2), (10574, 'Concluído', 1), (3133, 'Pendente', 1), (4948, 'Pendente', 2), (7372, 'Cancelado', 1), (4959, 'Concluído', 2), (9018, 'Concluído', 4), (8362, 'Concluído', 1), (1185, 'Pendente', 1), (7566, 'Concluído', 1), (6723, 'Concluído', 2), (8359, 'Pendente', 2), (4587, 'Pendente', 3), (2906, 'Pendente', 1), (2255, 'Concluído', 2), (5163, 'Pendente', 2), (4705, 'Cancelado', 3), (1770, 'Cancelado', 1), (7388, 'Pendente', 1), (9924, 'Concluído', 1), (3688, 'Pendente', 2), (8407, 'Cancelado', 2), (9626, 'Pendente', 3), (3499, 'Concluído', 2), (7105, 'Concluído', 2), (2254, 'Concluído', 1), (9536, 'Pendente', 2), (8522, 'Cancelado', 2), (6024, 'Pendente', 1), (8453, 'Cancelado', 2), (9673, 'Cancelado', 3), (4082, 'Concluído', 2), (6756, 'Pendente', 1) ...
# [(1, 'another', 'Take life win its without today.', Decimal('627.23'), 20, 'Roupas'), (2, 'key', 'Me effect detail laugh family perhaps anything beyond.', Decimal('276.75'), 90, 'Eletrônicos'), (3, 'kind', 'Two leg here opportunity long.', Decimal('254.76'), 99, 'Livros'), (4, 'data', 'Economy charge recognize bad develop detail.', Decimal('389.65'), 67, 'Roupas'), (5, 'institution', 'Already agency trip.', Decimal('220.61'), 84, 'Eletrônicos'), (8, 'executive', 'Although why but without name soldier respond born.', Decimal('409.19'), 47, 'Roupas'), (9, 'yeah', 'Along impact build center moment.', Decimal('482.39'), 3, 'Roupas'), (10, 'true', 'Class plan would.', Decimal('711.77'), 30, 'Livros'), (11, 'produce', 'Six business will million which very.', Decimal('624.13'), 83, 'Alimentos'), (12, 'identify', 'Per better nor half.', Decimal('580.89'), 16, 'Eletrônicos'), (13, 'baby', 'About plant style myself since.', Decimal('891.53'), 28, 'Livros'), (14, 'science', 'Town series most from different most.', Decimal('655.89'), 66, 'Alimentos'), (16, 'recently', 'Why school during leg.', Decimal('340.75'), 22, 'Móveis'), (18, 'impact', 'Daughter join apply lawyer yet address.', Decimal('558.72'), 85, 'Eletrônicos'), (19, 'goal', 'Focus case education choice seek.', Decimal('512.52'), 73, 'Alimentos'), (24, 'option', 'People social visit age consumer.', Decimal('203.51'), 3, 'Roupas'), (25, 'past', 'Wear church training each.', Decimal('541.09'), 29, 'Alimentos'), (26, 'true', 'Over however back thus.', Decimal('725.07'), 99, 'Alimentos'), (27, 'decade', 'Grow actually media son really.', Decimal('473.92'), 14, 'Móveis'), (29, 'outside', 'Indeed this up.', Decimal('56.53'), 35, 'Livros'), (30, 'product', 'Expect such south.', Decimal('838.11'), 46, 'Móveis'), (31, 'group', 'World team reach consumer.', Decimal('947.47'), 75, 'Móveis'), (33, 'oil', 'Meet east history sport.', Decimal('272.22'), 24, 'Eletrônicos'), (34, 'history', 'Up would join ready pass back.', Decimal('678.10'), 92, 'Móveis'), (37, 'staff', 'Company police brother speech management where against.', Decimal('572.21'), 18, 'Roupas'), (38, 'fall', 'Hotel across others include owner help single.', Decimal('55.38'), 43, 'Móveis'), (39, 'especially', 'Entire training better offer discussion.', Decimal('735.93'), 62, 'Eletrônicos'), (40, 'glass', 'Break environmental position.', Decimal('961.65'), 29, 'Eletrônicos'), (42, 'should', 'Choose finish information air book today.', Decimal('500.89'), 6, 'Roupas'), (43, 'teach', 'Ground director hear about stuff suddenly.', Decimal('98.36'), 48, 'Eletrônicos'), (45, 'later', 'Bill charge letter soldier full white.', Decimal('763.90'), 11, 'Móveis'), (46, 'likely', 'Skill recently perform myself newspaper mission meeting.', Decimal('182.32'), 27, 'Alimentos'), (47, 'allow', 'Manager attorney with late hospital face.', Decimal('773.27'), 57, 'Roupas'), (50, 'under', 'Would year consumer Congress without free.', Decimal('28.29'), 45, 'Livros'), (51, 'try', 'View several really their weight.', Decimal('399.25'), 82, 'Alimentos'), (52, 'along', 'Act race gas think security.', Decimal('36.15'), 13, 'Eletrônicos'), (54, 'notice', 'Nation camera apply technology.', Decimal('242.27'), 81, 'Roupas'), (55, 'fill', 'Information especially important much quickly seven suggest.', Decimal('550.65'), 41, 'Roupas'), (56, 'most', 'Chance century difficult.', Decimal('329.56'), 99, 'Livros'), (57, 'receive', 'War coach culture plan water first subject.', Decimal('349.78'), 26, 'Livros'), (58, 'church', 'Chair child agency budget.', Decimal('593.99'), 65, 'Alimentos'), (62, 'health', 'Usually great guy popular trial.', Decimal('996.73'), 47, 'Eletrônicos'), (63, 'knowledge', 'Imagine put from sign world seem west.', Decimal('31.25'), 82, 'Livros'), (64, 'loss', 'Concern answer art late attorney half parent.', Decimal('227.82'), 48, 'Alimentos'), (65, 'go', 'Suddenly can nothing.', Decimal('175.50'), 78, 'Roupas'), (66, 'four', 'Citizen quickly moth ...
# [('Michael Brown', 10), ('James Smith', 8), ('Timothy Taylor', 7), ('James Williams', 7), ('Matthew Williams', 6), ('William Smith', 6), ('Thomas Smith', 6), ('Michael Smith', 6), ('Lisa Johnson', 5), ('Edward Moore', 5)]
# [('Mais Caro', 15136, 'those', 'Determine day art key ten reach question dream.', Decimal('1000.00'), 43, 'Roupas'), ('Mais Barato', 4203, 'house', 'Often stuff talk Mrs ever big.', Decimal('10.01'), 44, 'Alimentos')]
# (Decimal('57.7627500000000000'),)
# [('James Hall', 3), ('John Vasquez', 2), ('Logan Lopez', 2), ('Wendy Hill', 2), ('Richard Phillips', 2), ('Melissa Moreno', 2), ('Mary Williams', 5), ('Jason Perez', 2), ('Elizabeth Myers', 2), ('Jason Reed', 2), ('Kelly Mckenzie', 2), ('Julia Torres', 2), ('Nathan White', 2), ('William White', 2), ('Kevin Wilson', 2), ('Morgan King', 2), ('Joseph Anderson', 2), ('David Baker', 2), ('Christine Rodriguez', 2), ('Daniel Thomas', 2), ('Tammy Rivera', 2), ('Brittany Jacobs', 2), ('Cheryl Harris', 2), ('Richard Kelly', 2), ('Christopher Romero', 2), ('John Gonzalez', 2), ('Tonya Smith', 2), ('Matthew Tran', 2), ('Christopher Johnson', 5), ('Christopher Rasmussen', 2), ('Christopher Bennett', 2), ('Bryan Walker', 3), ('David Roberts', 4), ('Jennifer Smith', 6), ('Kristen Smith', 2), ('Tara Hicks', 2), ('Susan Wilson', 2), ('Alyssa Smith', 5), ('Susan Jones', 3), ('Stephanie Williams', 5), ('Stephen Brown', 2), ('Nicholas Hill', 2), ('Sarah Patel', 2), ('Anne Miller', 2), ('Casey Johnson', 2), ('John Robinson', 3), ('Michael Jones', 8), ('Sarah Anderson', 2), ('Robert Miller', 6), ('Angela Coleman', 2), ('Daniel Green', 2), ('Jonathan Garcia', 2), ('William Flores', 2), ('Kenneth Williams', 2), ('Sharon Schmidt', 2), ('Daniel Martin', 2), ('Michael Thompson', 2), ('Lisa Simmons', 2), ('Jacob Ward', 2), ('Michael Williams', 2), ('Jennifer Myers', 2), ('David Wright', 2), ('Christine Ferguson', 2), ('Robert Gutierrez', 2), ('Robert Robinson', 2), ('Amy Dixon', 2), ('Nicholas Miller', 2), ('Steven George', 2), ('Edward Moore', 4), ('Alicia Gray', 3), ('Matthew Martin', 2), ('Samantha Garcia', 5), ('Jeremy Bryant', 2), ('John Kirk', 2), ('Michael Moore', 2), ('Kelly Taylor', 2), ('Bryan Wilson', 2), ('Matthew Williams', 7), ('Michael Brown', 11), ('Jamie Richardson', 2), ('Mary Strickland', 2), ('Mary Rodriguez', 2), ('Brandon Cook', 2), ('William Clark', 2), ('Lisa Owens', 2), ('James Rodriguez', 3), ('Lisa Smith', 5), ('Donald Richardson', 2), ('Andrew Williams', 2), ('Michael Sanchez', 2), ('Caleb Harris', 2), ('Margaret Martin', 3), ('Jennifer Allen', 2), ('Cynthia Brown', 2), ('Brian Bishop', 2), ('Daniel Hernandez', 3), ('Patricia Garcia', 2), ('Peter Martinez', 2), ('David Fisher', 2), ('Mary Jackson', 2), ('William Stanley', 2), ('Thomas Bean', 2), ('Sara Jones', 3), ('Melissa Nelson', 2), ('Melissa Perez', 3), ('Michael Warner', 2), ('Brittany Johnson', 2), ('Michael Rodriguez', 3), ('Jessica Sullivan', 2), ('Theresa Edwards', 2), ('Tammy Garcia', 2), ('Amber Morris', 2), ('Victoria Marsh', 2), ('Elizabeth Gonzalez', 4), ('John Thomas', 4), ('Scott Love', 2), ('Brady Taylor', 2), ('James Simon', 2), ('Daniel Baker', 2), ('Jason Johnson', 4), ('Amber Smith', 2), ('Kimberly Davis', 2), ('Michael Anderson', 6), ('Nicholas Torres', 3), ('Jennifer Davis', 3), ('Kevin Brown', 2), ('Thomas Jones', 2), ('Edward Williams', 2), ('Jerry Murphy', 2), ('Joseph Moore', 3), ('Jonathan Hayes', 2), ('Rebecca Taylor', 3), ('Jennifer Lewis', 2), ('Charles Williams', 2), ('Michael Colon', 2), ('Kimberly Taylor', 2), ('Jessica Brown', 3), ('Charlene Harris', 2), ('Joseph Carlson', 2), ('Jennifer Jones', 2), ('David Atkinson', 2), ('Sean Rogers', 2), ('James Phillips', 3), ('Phillip Harris', 2), ('John Rodriguez', 8), ('Stephen Richardson', 2), ('Timothy Ellis', 2), ('Michael Phillips', 3), ('Donald Brown', 2), ('Brian Williams', 2), ('Tanya Price', 2), ('William Jones', 4), ('Jennifer Johnson', 2), ('Brian Jones', 2), ('David Rodriguez', 3), ('Christopher Nelson', 2), ('Timothy Myers', 3), ('Andrew Levy', 2), ('David Olson', 2), ('James Stewart', 2), ('Lisa Thomas', 3), ('Olivia Woods', 2), ('Melissa Sullivan', 2), ('Matthew Johnson', 3), ('Eric Green', 2), ('Elizabeth Moore', 2), ('Jessica Silva', 2), ('Andrea Davis', 2), ('Lisa Ortiz', 2), ('Megan Brown', 2), ('Kelly Nguyen', 3), ('John Evans', 2), ('Kimberly Rodriguez', 2), ('Melissa Hill', 3), ('William Bryant', 2), ('Jeremy Miller', 2), ('Kevin Smith', 6), ('David Brown', 5), ('Nicholas Roberts ...
# [(647, datetime.date(2024, 7, 9), 'Concluído', Decimal('4740.26'), 10730), (650, datetime.date(2024, 1, 23), 'Concluído', Decimal('1051.60'), 15886), (657, datetime.date(2024, 7, 14), 'Pendente', Decimal('1638.95'), 534), (660, datetime.date(2024, 4, 23), 'Pendente', Decimal('3250.24'), 914), (672, datetime.date(2024, 7, 14), 'Concluído', Decimal('4989.39'), 19934), (678, datetime.date(2024, 6, 11), 'Cancelado', Decimal('4991.35'), 2267), (706, datetime.date(2024, 6, 19), 'Cancelado', Decimal('1411.46'), 16800), (713, datetime.date(2024, 4, 7), 'Cancelado', Decimal('1869.46'), 12493), (724, datetime.date(2024, 2, 27), 'Concluído', Decimal('383.89'), 11911), (730, datetime.date(2024, 5, 13), 'Cancelado', Decimal('3697.60'), 15325), (743, datetime.date(2024, 5, 14), 'Concluído', Decimal('121.44'), 6208), (779, datetime.date(2024, 1, 26), 'Pendente', Decimal('863.12'), 7928), (783, datetime.date(2024, 3, 15), 'Concluído', Decimal('1731.51'), 1181), (813, datetime.date(2024, 5, 31), 'Pendente', Decimal('4866.92'), 7300), (815, datetime.date(2024, 4, 17), 'Cancelado', Decimal('70.18'), 12962), (825, datetime.date(2024, 7, 3), 'Concluído', Decimal('4773.28'), 15053), (837, datetime.date(2024, 4, 19), 'Cancelado', Decimal('187.48'), 5100), (849, datetime.date(2024, 7, 8), 'Cancelado', Decimal('2025.77'), 15346), (851, datetime.date(2024, 1, 25), 'Pendente', Decimal('3600.17'), 7319), (857, datetime.date(2024, 2, 7), 'Pendente', Decimal('3532.25'), 5677), (861, datetime.date(2024, 2, 2), 'Cancelado', Decimal('592.16'), 5101), (863, datetime.date(2024, 7, 13), 'Cancelado', Decimal('2346.49'), 14181), (866, datetime.date(2024, 3, 3), 'Concluído', Decimal('3020.15'), 5582), (869, datetime.date(2024, 5, 4), 'Pendente', Decimal('2425.73'), 7274), (884, datetime.date(2024, 6, 21), 'Concluído', Decimal('1204.56'), 2520), (902, datetime.date(2024, 5, 22), 'Cancelado', Decimal('3998.52'), 15148), (908, datetime.date(2024, 6, 23), 'Concluído', Decimal('1337.88'), 2342), (923, datetime.date(2024, 3, 14), 'Cancelado', Decimal('2217.78'), 569), (924, datetime.date(2024, 4, 5), 'Cancelado', Decimal('4306.85'), 16471), (947, datetime.date(2024, 2, 16), 'Cancelado', Decimal('430.40'), 12845), (968, datetime.date(2024, 2, 7), 'Cancelado', Decimal('3381.16'), 3630), (973, datetime.date(2024, 7, 3), 'Pendente', Decimal('272.91'), 14628), (974, datetime.date(2024, 1, 27), 'Pendente', Decimal('895.34'), 17812), (991, datetime.date(2024, 6, 27), 'Pendente', Decimal('2701.77'), 18086), (1009, datetime.date(2024, 3, 31), 'Cancelado', Decimal('3238.62'), 17829), (1019, datetime.date(2024, 2, 20), 'Concluído', Decimal('1345.04'), 5085), (1044, datetime.date(2024, 3, 13), 'Pendente', Decimal('1952.84'), 1627), (1065, datetime.date(2024, 4, 5), 'Cancelado', Decimal('2550.70'), 3153), (1071, datetime.date(2024, 2, 12), 'Pendente', Decimal('815.91'), 1377), (1073, datetime.date(2024, 2, 3), 'Cancelado', Decimal('3511.72'), 4162), (1090, datetime.date(2024, 4, 14), 'Cancelado', Decimal('1805.50'), 17878), (1094, datetime.date(2024, 6, 1), 'Pendente', Decimal('4008.20'), 16188), (1098, datetime.date(2024, 5, 23), 'Cancelado', Decimal('2126.51'), 1935), (1114, datetime.date(2024, 3, 12), 'Pendente', Decimal('1589.58'), 9040), (1126, datetime.date(2024, 1, 9), 'Cancelado', Decimal('4741.85'), 3208), (1132, datetime.date(2024, 7, 5), 'Concluído', Decimal('2753.87'), 15459), (1134, datetime.date(2024, 2, 21), 'Cancelado', Decimal('974.24'), 4811), (1137, datetime.date(2024, 2, 11), 'Cancelado', Decimal('624.59'), 13396), (1139, datetime.date(2024, 5, 22), 'Concluído', Decimal('2365.04'), 18228), (1148, datetime.date(2024, 3, 20), 'Pendente', Decimal('2260.91'), 933), (1171, datetime.date(2024, 5, 19), 'Pendente', Decimal('4501.39'), 8875), (1182, datetime.date(2024, 7, 11), 'Cancelado', Decimal('4482.39'), 8980), (1185, datetime.date(2024, 5, 18), 'Pendente', Decimal('1739.92'), 7956), (1201, datetime.date(2024, 2, 6), 'Cancelado', Decimal('3775.24'), 7732), (1239, date ...
# [('another', 'Roupas', 'Em Estoque'), ('key', 'Eletrônicos', 'Em Estoque'), ('kind', 'Livros', 'Em Estoque'), ('data', 'Roupas', 'Em Estoque'), ('institution', 'Eletrônicos', 'Em Estoque'), ('bar', 'Eletrônicos', 'Em Estoque'), ('very', 'Roupas', 'Em Estoque'), ('executive', 'Roupas', 'Em Estoque'), ('yeah', 'Roupas', 'Em Estoque'), ('true', 'Livros', 'Em Estoque'), ('produce', 'Alimentos', 'Em Estoque'), ('identify', 'Eletrônicos', 'Em Estoque'), ('baby', 'Livros', 'Em Estoque'), ('science', 'Alimentos', 'Em Estoque'), ('cultural', 'Livros', 'Em Estoque'), ('recently', 'Móveis', 'Em Estoque'), ('pull', 'Livros', 'Em Estoque'), ('impact', 'Eletrônicos', 'Em Estoque'), ('goal', 'Alimentos', 'Em Estoque'), ('money', 'Roupas', 'Em Estoque'), ('southern', 'Eletrônicos', 'Em Estoque'), ('happy', 'Eletrônicos', 'Em Estoque'), ('exactly', 'Alimentos', 'Em Estoque'), ('option', 'Roupas', 'Em Estoque'), ('past', 'Alimentos', 'Em Estoque'), ('true', 'Alimentos', 'Em Estoque'), ('decade', 'Móveis', 'Em Estoque'), ('fill', 'Eletrônicos', 'Em Estoque'), ('outside', 'Livros', 'Em Estoque'), ('product', 'Móveis', 'Em Estoque'), ('group', 'Móveis', 'Em Estoque'), ('position', 'Móveis', 'Em Estoque'), ('oil', 'Eletrônicos', 'Em Estoque'), ('history', 'Móveis', 'Em Estoque'), ('eye', 'Roupas', 'Em Estoque'), ('from', 'Roupas', 'Em Estoque'), ('staff', 'Roupas', 'Em Estoque'), ('fall', 'Móveis', 'Em Estoque'), ('especially', 'Eletrônicos', 'Em Estoque'), ('glass', 'Eletrônicos', 'Em Estoque'), ('type', 'Eletrônicos', 'Em Estoque'), ('should', 'Roupas', 'Em Estoque'), ('teach', 'Eletrônicos', 'Em Estoque'), ('despite', 'Alimentos', 'Em Estoque'), ('later', 'Móveis', 'Em Estoque'), ('likely', 'Alimentos', 'Em Estoque'), ('allow', 'Roupas', 'Em Estoque'), ('man', 'Eletrônicos', 'Em Estoque'), ('official', 'Móveis', 'Em Estoque'), ('under', 'Livros', 'Em Estoque'), ('try', 'Alimentos', 'Em Estoque'), ('along', 'Eletrônicos', 'Em Estoque'), ('action', 'Eletrônicos', 'Em Estoque'), ('notice', 'Roupas', 'Em Estoque'), ('fill', 'Roupas', 'Em Estoque'), ('most', 'Livros', 'Em Estoque'), ('receive', 'Livros', 'Em Estoque'), ('church', 'Alimentos', 'Em Estoque'), ('kind', 'Livros', 'Em Estoque'), ('perform', 'Roupas', 'Em Estoque'), ('operation', 'Alimentos', 'Em Estoque'), ('health', 'Eletrônicos', 'Em Estoque'), ('knowledge', 'Livros', 'Em Estoque'), ('loss', 'Alimentos', 'Em Estoque'), ('go', 'Roupas', 'Em Estoque'), ('four', 'Eletrônicos', 'Em Estoque'), ('court', 'Roupas', 'Em Estoque'), ('may', 'Roupas', 'Em Estoque'), ('develop', 'Eletrônicos', 'Em Estoque'), ('beautiful', 'Roupas', 'Em Estoque'), ('parent', 'Roupas', 'Em Estoque'), ('tonight', 'Livros', 'Em Estoque'), ('pull', 'Roupas', 'Em Estoque'), ('leader', 'Móveis', 'Em Estoque'), ('or', 'Móveis', 'Em Estoque'), ('hold', 'Livros', 'Em Estoque'), ('fill', 'Eletrônicos', 'Em Estoque'), ('sure', 'Eletrônicos', 'Em Estoque'), ('do', 'Alimentos', 'Em Estoque'), ('see', 'Móveis', 'Em Estoque'), ('identify', 'Livros', 'Em Estoque'), ('security', 'Eletrônicos', 'Em Estoque'), ('summer', 'Eletrônicos', 'Em Estoque'), ('myself', 'Roupas', 'Em Estoque'), ('election', 'Roupas', 'Em Estoque'), ('reason', 'Roupas', 'Em Estoque'), ('society', 'Alimentos', 'Em Estoque'), ('play', 'Livros', 'Em Estoque'), ('account', 'Móveis', 'Em Estoque'), ('nature', 'Alimentos', 'Em Estoque'), ('nor', 'Roupas', 'Em Estoque'), ('huge', 'Roupas', 'Em Estoque'), ('a', 'Móveis', 'Em Estoque'), ('program', 'Eletrônicos', 'Em Estoque'), ('science', 'Eletrônicos', 'Em Estoque'), ('player', 'Eletrônicos', 'Em Estoque'), ('sell', 'Alimentos', 'Em Estoque'), ('off', 'Alimentos', 'Em Estoque'), ('especially', 'Roupas', 'Em Estoque'), ('exist', 'Móveis', 'Em Estoque'), ('increase', 'Móveis', 'Em Estoque'), ('low', 'Móveis', 'Em Estoque'), ('degree', 'Livros', 'Em Estoque'), ('how', 'Alimentos', 'Em Estoque'), ('land', 'Alimentos', 'Em Estoque'), ('at', 'Roupas', 'Em Estoque'), ('rather', 'Livros', 'Em Estoque'), ('almost', 'Roupas', ' ...

# %% [markdown]
# #### Fechar a conexão:

# %%
cursor.close()
conn.close()
